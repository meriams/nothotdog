# %% [markdown]
# # Semantic Segmentation Exercises
#
# Based on exercise from DLCV 2019 by ASM Shihavuddin and Ricardo Cruz

# %% [markdown]
# The data used for this exercise stems from the ISBI cell tracking challenge http://celltrackingchallenge.net/. The data loader below assumes that you are working on the HPC machines with the data located at
#
# /dtu/datasets1/02516/phc_data
#
# If this is not the case, you will have to adapt the data loader accordingly.
#
# These are microscopy images taken over time of different cells that move around in the image plane; the images you will be working with have been processed to contain only a single cell each.

# %%
pip install torchsummary
# Out:
# Collecting torchsummary
#   Downloading torchsummary-1.5.1-py3-none-any.whl (2.8 kB)
# Installing collected packages: torchsummary
# Successfully installed torchsummary-1.5.1
# WARNING: You are using pip version 21.1; however, version 23.3.2 is available.
# You should consider upgrading via the '/zhome/79/6/181436/venv_1/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import numpy as np
import glob
import PIL.Image as Image

# pip install torchsummary
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.datasets as datasets
from torch.utils.data import DataLoader
import torchvision.transforms as transforms
from torchvision import models
from torchsummary import summary
import torch.optim as optim
from time import time

import matplotlib.pyplot as plt
from IPython.display import clear_output

# %% [markdown]
# Next, the data loader

# %%
folder_path = os.path.join('/dtu/datasets1/02516/PH2_Dataset_images/')
image_folders = os.listdir(folder_path)
# Out:
# IMD002
# IMD003
# IMD004
# IMD006
# IMD008
# IMD009
# IMD010
# IMD013
# IMD014
# IMD015
# IMD016
# IMD017
# IMD018
# IMD019
# IMD020
# IMD021
# IMD022
# IMD023
# IMD024
# IMD025
# IMD027
# IMD030
# IMD031
# IMD032
# IMD033
# IMD035
# IMD036
# IMD037
# IMD038
# IMD039
# IMD040
# IMD041
# IMD042
# IMD043
# IMD044
# IMD045
# IMD047
# IMD048
# IMD049
# IMD050
# IMD057
# IMD058
# IMD061
# IMD063
# IMD064
# IMD065
# IMD075
# IMD076
# IMD078
# IMD080
# IMD085
# IMD088
# IMD090
# IMD091
# IMD092
# IMD101
# IMD103
# IMD105
# IMD107
# IMD108
# IMD112
# IMD118
# IMD120
# IMD125
# IMD126
# IMD132
# IMD133
# IMD134
# IMD135
# IMD137
# IMD138
# IMD139
# IMD140
# IMD142
# IMD143
# IMD144
# IMD146
# IMD147
# IMD149
# IMD150
# IMD152
# IMD153
# IMD154
# IMD155
# IMD156
# IMD157
# IMD159
# IMD160
# IMD161
# IMD162
# IMD164
# IMD166
# IMD168
# IMD169
# IMD170
# IMD171
# IMD173
# IMD175
# IMD176
# IMD177
# IMD182
# IMD196
# IMD197
# IMD198
# IMD199
# IMD200
# IMD203
# IMD204
# IMD206
# IMD207
# IMD208
# IMD210
# IMD211
# IMD219
# IMD226
# IMD240
# IMD242
# IMD243
# IMD251
# IMD254
# IMD256
# IMD278
# IMD279
# IMD280
# IMD284
# IMD285
# IMD304
# IMD305
# IMD306
# IMD312
# IMD328
# IMD331
# IMD339
# IMD347
# IMD348
# IMD349
# IMD356
# IMD360
# IMD364
# IMD365
# IMD367
# IMD368
# IMD369
# IMD370
# IMD371
# IMD372
# IMD374
# IMD375
# IMD376
# IMD378
# IMD379
# IMD380
# IMD381
# IMD382
# IMD383
# IMD384
# IMD385
# IMD386
# IMD388
# IMD389
# IMD390
# IMD392
# IMD393
# IMD394
# IMD395
# IMD396
# IMD397
# IMD398
# IMD399
# IMD400
# IMD402
# IMD403
# IMD404
# IMD405
# IMD406
# IMD407
# IMD408
# IMD409
# IMD410
# IMD411
# IMD413
# IMD417
# IMD418
# IMD419
# IMD420
# IMD421
# IMD423
# IMD424
# IMD425
# IMD426
# IMD427
# IMD429
# IMD430
# IMD431
# IMD432
# IMD433
# IMD434
# IMD435
# IMD436
# IMD437

# %%
data_path = '/dtu/datasets1/02516/PH2_Dataset_images/'
#data_path = './phc_data'
class PhC(torch.utils.data.Dataset):
    def __init__(self, train, transform, data_path=data_path):
        'Initialization'
        self.transform = transform
        image_paths = []
        for folder in image_folders:
            image_paths.append(data_path + folder + "/" + folder + "_Dermoscopic_Image" + "/" + folder + ".bmp")

        label_paths = []
        for folder in image_folders:
            label_paths.append(data_path + folder + "/" + folder + "_lesion" + "/" + folder + "_lesion.bmp")
        
        # data_path = os.path.join(data_path, 'train' if train else 'test')
        self.image_paths = sorted(image_paths)
        self.label_paths = sorted(label_paths)
        
    def __len__(self):
        'Returns the total number of samples'
        return len(self.image_paths)

    def __getitem__(self, idx):
        'Generates one sample of data'
        image_path = self.image_paths[idx]
        label_path = self.label_paths[idx]
        
        image = Image.open(image_path)
        label = Image.open(label_path)
        Y = self.transform(label)
        X = self.transform(image)
        return X, Y

# %% [markdown]
# In principle, the images could have different sizes. Let's resize them all to $128\times128$ pixels, using the torchvision Resize.

# %%
size = 128
train_transform = transforms.Compose([transforms.Resize((size, size)), 
                                    transforms.ToTensor()])
test_transform = transforms.Compose([transforms.Resize((size, size)), 
                                    transforms.ToTensor()])

batch_size = 6
trainset = PhC(train=True, transform=train_transform)
train_loader = DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=3)
testset = PhC(train=False, transform=test_transform)
test_loader = DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=3)
# Out:
# /dtu/datasets1/02516/PH2_Dataset_images/IMD002/IMD002_Dermoscopic_Image/IMD002.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD003/IMD003_Dermoscopic_Image/IMD003.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD004/IMD004_Dermoscopic_Image/IMD004.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD006/IMD006_Dermoscopic_Image/IMD006.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD008/IMD008_Dermoscopic_Image/IMD008.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD009/IMD009_Dermoscopic_Image/IMD009.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD010/IMD010_Dermoscopic_Image/IMD010.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD013/IMD013_Dermoscopic_Image/IMD013.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD014/IMD014_Dermoscopic_Image/IMD014.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD015/IMD015_Dermoscopic_Image/IMD015.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD016/IMD016_Dermoscopic_Image/IMD016.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD017/IMD017_Dermoscopic_Image/IMD017.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD018/IMD018_Dermoscopic_Image/IMD018.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD019/IMD019_Dermoscopic_Image/IMD019.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD020/IMD020_Dermoscopic_Image/IMD020.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD021/IMD021_Dermoscopic_Image/IMD021.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD022/IMD022_Dermoscopic_Image/IMD022.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD023/IMD023_Dermoscopic_Image/IMD023.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD024/IMD024_Dermoscopic_Image/IMD024.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD025/IMD025_Dermoscopic_Image/IMD025.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD027/IMD027_Dermoscopic_Image/IMD027.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD030/IMD030_Dermoscopic_Image/IMD030.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD031/IMD031_Dermoscopic_Image/IMD031.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD032/IMD032_Dermoscopic_Image/IMD032.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD033/IMD033_Dermoscopic_Image/IMD033.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD035/IMD035_Dermoscopic_Image/IMD035.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD036/IMD036_Dermoscopic_Image/IMD036.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD037/IMD037_Dermoscopic_Image/IMD037.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD038/IMD038_Dermoscopic_Image/IMD038.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD039/IMD039_Dermoscopic_Image/IMD039.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD040/IMD040_Dermoscopic_Image/IMD040.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD041/IMD041_Dermoscopic_Image/IMD041.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD042/IMD042_Dermoscopic_Image/IMD042.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD043/IMD043_Dermoscopic_Image/IMD043.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD044/IMD044_Dermoscopic_Image/IMD044.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD045/IMD045_Dermoscopic_Image/IMD045.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD047/IMD047_Dermoscopic_Image/IMD047.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD048/IMD048_Dermoscopic_Image/IMD048.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD049/IMD049_Dermoscopic_Image/IMD049.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD050/IMD050_Dermoscopic_Image/IMD050.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD057/IMD057_Dermoscopic_Image/IMD057.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD058/IMD058_Dermoscopic_Image/IMD058.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD061/IMD061_Dermoscopic_Image/IMD061.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD063/IMD063_Dermoscopic_Image/IMD063.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD064/IMD064_Dermoscopic_Image/IMD064.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD065/IMD065_Dermoscopic_Image/IMD065.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD075/IMD075_Dermoscopic_Image/IMD075.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD076/IMD076_Dermoscopic_Image/IMD076.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD078/IMD078_Dermoscopic_Image/IMD078.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD080/IMD080_Dermoscopic_Image/IMD080.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD085/IMD085_Dermoscopic_Image/IMD085.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD088/IMD088_Dermoscopic_Image/IMD088.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD090/IMD090_Dermoscopic_Image/IMD090.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD091/IMD091_Dermoscopic_Image/IMD091.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD092/IMD092_Dermoscopic_Image/IMD092.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD101/IMD101_Dermoscopic_Image/IMD101.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD103/IMD103_Dermoscopic_Image/IMD103.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD105/IMD105_Dermoscopic_Image/IMD105.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD107/IMD107_Dermoscopic_Image/IMD107.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD108/IMD108_Dermoscopic_Image/IMD108.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD112/IMD112_Dermoscopic_Image/IMD112.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD118/IMD118_Dermoscopic_Image/IMD118.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD120/IMD120_Dermoscopic_Image/IMD120.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD125/IMD125_Dermoscopic_Image/IMD125.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD126/IMD126_Dermoscopic_Image/IMD126.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD132/IMD132_Dermoscopic_Image/IMD132.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD133/IMD133_Dermoscopic_Image/IMD133.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD134/IMD134_Dermoscopic_Image/IMD134.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD135/IMD135_Dermoscopic_Image/IMD135.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD137/IMD137_Dermoscopic_Image/IMD137.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD138/IMD138_Dermoscopic_Image/IMD138.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD139/IMD139_Dermoscopic_Image/IMD139.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD140/IMD140_Dermoscopic_Image/IMD140.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD142/IMD142_Dermoscopic_Image/IMD142.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD143/IMD143_Dermoscopic_Image/IMD143.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD144/IMD144_Dermoscopic_Image/IMD144.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD146/IMD146_Dermoscopic_Image/IMD146.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD147/IMD147_Dermoscopic_Image/IMD147.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD149/IMD149_Dermoscopic_Image/IMD149.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD150/IMD150_Dermoscopic_Image/IMD150.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD152/IMD152_Dermoscopic_Image/IMD152.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD153/IMD153_Dermoscopic_Image/IMD153.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD154/IMD154_Dermoscopic_Image/IMD154.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD155/IMD155_Dermoscopic_Image/IMD155.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD156/IMD156_Dermoscopic_Image/IMD156.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD157/IMD157_Dermoscopic_Image/IMD157.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD159/IMD159_Dermoscopic_Image/IMD159.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD160/IMD160_Dermoscopic_Image/IMD160.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD161/IMD161_Dermoscopic_Image/IMD161.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD162/IMD162_Dermoscopic_Image/IMD162.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD164/IMD164_Dermoscopic_Image/IMD164.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD166/IMD166_Dermoscopic_Image/IMD166.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD168/IMD168_Dermoscopic_Image/IMD168.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD169/IMD169_Dermoscopic_Image/IMD169.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD170/IMD170_Dermoscopic_Image/IMD170.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD171/IMD171_Dermoscopic_Image/IMD171.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD173/IMD173_Dermoscopic_Image/IMD173.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD175/IMD175_Dermoscopic_Image/IMD175.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD176/IMD176_Dermoscopic_Image/IMD176.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD177/IMD177_Dermoscopic_Image/IMD177.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD182/IMD182_Dermoscopic_Image/IMD182.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD196/IMD196_Dermoscopic_Image/IMD196.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD197/IMD197_Dermoscopic_Image/IMD197.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD198/IMD198_Dermoscopic_Image/IMD198.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD199/IMD199_Dermoscopic_Image/IMD199.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD200/IMD200_Dermoscopic_Image/IMD200.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD203/IMD203_Dermoscopic_Image/IMD203.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD204/IMD204_Dermoscopic_Image/IMD204.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD206/IMD206_Dermoscopic_Image/IMD206.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD207/IMD207_Dermoscopic_Image/IMD207.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD208/IMD208_Dermoscopic_Image/IMD208.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD210/IMD210_Dermoscopic_Image/IMD210.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD211/IMD211_Dermoscopic_Image/IMD211.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD219/IMD219_Dermoscopic_Image/IMD219.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD226/IMD226_Dermoscopic_Image/IMD226.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD240/IMD240_Dermoscopic_Image/IMD240.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD242/IMD242_Dermoscopic_Image/IMD242.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD243/IMD243_Dermoscopic_Image/IMD243.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD251/IMD251_Dermoscopic_Image/IMD251.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD254/IMD254_Dermoscopic_Image/IMD254.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD256/IMD256_Dermoscopic_Image/IMD256.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD278/IMD278_Dermoscopic_Image/IMD278.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD279/IMD279_Dermoscopic_Image/IMD279.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD280/IMD280_Dermoscopic_Image/IMD280.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD284/IMD284_Dermoscopic_Image/IMD284.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD285/IMD285_Dermoscopic_Image/IMD285.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD304/IMD304_Dermoscopic_Image/IMD304.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD305/IMD305_Dermoscopic_Image/IMD305.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD306/IMD306_Dermoscopic_Image/IMD306.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD312/IMD312_Dermoscopic_Image/IMD312.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD328/IMD328_Dermoscopic_Image/IMD328.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD331/IMD331_Dermoscopic_Image/IMD331.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD339/IMD339_Dermoscopic_Image/IMD339.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD347/IMD347_Dermoscopic_Image/IMD347.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD348/IMD348_Dermoscopic_Image/IMD348.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD349/IMD349_Dermoscopic_Image/IMD349.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD356/IMD356_Dermoscopic_Image/IMD356.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD360/IMD360_Dermoscopic_Image/IMD360.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD364/IMD364_Dermoscopic_Image/IMD364.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD365/IMD365_Dermoscopic_Image/IMD365.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD367/IMD367_Dermoscopic_Image/IMD367.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD368/IMD368_Dermoscopic_Image/IMD368.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD369/IMD369_Dermoscopic_Image/IMD369.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD370/IMD370_Dermoscopic_Image/IMD370.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD371/IMD371_Dermoscopic_Image/IMD371.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD372/IMD372_Dermoscopic_Image/IMD372.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD374/IMD374_Dermoscopic_Image/IMD374.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD375/IMD375_Dermoscopic_Image/IMD375.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD376/IMD376_Dermoscopic_Image/IMD376.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD378/IMD378_Dermoscopic_Image/IMD378.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD379/IMD379_Dermoscopic_Image/IMD379.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD380/IMD380_Dermoscopic_Image/IMD380.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD381/IMD381_Dermoscopic_Image/IMD381.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD382/IMD382_Dermoscopic_Image/IMD382.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD383/IMD383_Dermoscopic_Image/IMD383.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD384/IMD384_Dermoscopic_Image/IMD384.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD385/IMD385_Dermoscopic_Image/IMD385.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD386/IMD386_Dermoscopic_Image/IMD386.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD388/IMD388_Dermoscopic_Image/IMD388.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD389/IMD389_Dermoscopic_Image/IMD389.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD390/IMD390_Dermoscopic_Image/IMD390.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD392/IMD392_Dermoscopic_Image/IMD392.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD393/IMD393_Dermoscopic_Image/IMD393.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD394/IMD394_Dermoscopic_Image/IMD394.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD395/IMD395_Dermoscopic_Image/IMD395.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD396/IMD396_Dermoscopic_Image/IMD396.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD397/IMD397_Dermoscopic_Image/IMD397.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD398/IMD398_Dermoscopic_Image/IMD398.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD399/IMD399_Dermoscopic_Image/IMD399.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD400/IMD400_Dermoscopic_Image/IMD400.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD402/IMD402_Dermoscopic_Image/IMD402.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD403/IMD403_Dermoscopic_Image/IMD403.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD404/IMD404_Dermoscopic_Image/IMD404.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD405/IMD405_Dermoscopic_Image/IMD405.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD406/IMD406_Dermoscopic_Image/IMD406.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD407/IMD407_Dermoscopic_Image/IMD407.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD408/IMD408_Dermoscopic_Image/IMD408.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD409/IMD409_Dermoscopic_Image/IMD409.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD410/IMD410_Dermoscopic_Image/IMD410.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD411/IMD411_Dermoscopic_Image/IMD411.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD413/IMD413_Dermoscopic_Image/IMD413.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD417/IMD417_Dermoscopic_Image/IMD417.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD418/IMD418_Dermoscopic_Image/IMD418.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD419/IMD419_Dermoscopic_Image/IMD419.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD420/IMD420_Dermoscopic_Image/IMD420.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD421/IMD421_Dermoscopic_Image/IMD421.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD423/IMD423_Dermoscopic_Image/IMD423.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD424/IMD424_Dermoscopic_Image/IMD424.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD425/IMD425_Dermoscopic_Image/IMD425.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD426/IMD426_Dermoscopic_Image/IMD426.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD427/IMD427_Dermoscopic_Image/IMD427.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD429/IMD429_Dermoscopic_Image/IMD429.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD430/IMD430_Dermoscopic_Image/IMD430.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD431/IMD431_Dermoscopic_Image/IMD431.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD432/IMD432_Dermoscopic_Image/IMD432.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD433/IMD433_Dermoscopic_Image/IMD433.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD434/IMD434_Dermoscopic_Image/IMD434.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD435/IMD435_Dermoscopic_Image/IMD435.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD436/IMD436_Dermoscopic_Image/IMD436.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD437/IMD437_Dermoscopic_Image/IMD437.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD002/IMD002_Dermoscopic_Image/IMD002.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD003/IMD003_Dermoscopic_Image/IMD003.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD004/IMD004_Dermoscopic_Image/IMD004.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD006/IMD006_Dermoscopic_Image/IMD006.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD008/IMD008_Dermoscopic_Image/IMD008.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD009/IMD009_Dermoscopic_Image/IMD009.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD010/IMD010_Dermoscopic_Image/IMD010.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD013/IMD013_Dermoscopic_Image/IMD013.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD014/IMD014_Dermoscopic_Image/IMD014.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD015/IMD015_Dermoscopic_Image/IMD015.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD016/IMD016_Dermoscopic_Image/IMD016.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD017/IMD017_Dermoscopic_Image/IMD017.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD018/IMD018_Dermoscopic_Image/IMD018.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD019/IMD019_Dermoscopic_Image/IMD019.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD020/IMD020_Dermoscopic_Image/IMD020.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD021/IMD021_Dermoscopic_Image/IMD021.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD022/IMD022_Dermoscopic_Image/IMD022.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD023/IMD023_Dermoscopic_Image/IMD023.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD024/IMD024_Dermoscopic_Image/IMD024.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD025/IMD025_Dermoscopic_Image/IMD025.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD027/IMD027_Dermoscopic_Image/IMD027.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD030/IMD030_Dermoscopic_Image/IMD030.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD031/IMD031_Dermoscopic_Image/IMD031.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD032/IMD032_Dermoscopic_Image/IMD032.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD033/IMD033_Dermoscopic_Image/IMD033.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD035/IMD035_Dermoscopic_Image/IMD035.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD036/IMD036_Dermoscopic_Image/IMD036.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD037/IMD037_Dermoscopic_Image/IMD037.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD038/IMD038_Dermoscopic_Image/IMD038.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD039/IMD039_Dermoscopic_Image/IMD039.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD040/IMD040_Dermoscopic_Image/IMD040.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD041/IMD041_Dermoscopic_Image/IMD041.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD042/IMD042_Dermoscopic_Image/IMD042.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD043/IMD043_Dermoscopic_Image/IMD043.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD044/IMD044_Dermoscopic_Image/IMD044.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD045/IMD045_Dermoscopic_Image/IMD045.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD047/IMD047_Dermoscopic_Image/IMD047.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD048/IMD048_Dermoscopic_Image/IMD048.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD049/IMD049_Dermoscopic_Image/IMD049.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD050/IMD050_Dermoscopic_Image/IMD050.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD057/IMD057_Dermoscopic_Image/IMD057.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD058/IMD058_Dermoscopic_Image/IMD058.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD061/IMD061_Dermoscopic_Image/IMD061.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD063/IMD063_Dermoscopic_Image/IMD063.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD064/IMD064_Dermoscopic_Image/IMD064.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD065/IMD065_Dermoscopic_Image/IMD065.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD075/IMD075_Dermoscopic_Image/IMD075.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD076/IMD076_Dermoscopic_Image/IMD076.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD078/IMD078_Dermoscopic_Image/IMD078.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD080/IMD080_Dermoscopic_Image/IMD080.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD085/IMD085_Dermoscopic_Image/IMD085.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD088/IMD088_Dermoscopic_Image/IMD088.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD090/IMD090_Dermoscopic_Image/IMD090.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD091/IMD091_Dermoscopic_Image/IMD091.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD092/IMD092_Dermoscopic_Image/IMD092.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD101/IMD101_Dermoscopic_Image/IMD101.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD103/IMD103_Dermoscopic_Image/IMD103.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD105/IMD105_Dermoscopic_Image/IMD105.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD107/IMD107_Dermoscopic_Image/IMD107.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD108/IMD108_Dermoscopic_Image/IMD108.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD112/IMD112_Dermoscopic_Image/IMD112.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD118/IMD118_Dermoscopic_Image/IMD118.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD120/IMD120_Dermoscopic_Image/IMD120.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD125/IMD125_Dermoscopic_Image/IMD125.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD126/IMD126_Dermoscopic_Image/IMD126.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD132/IMD132_Dermoscopic_Image/IMD132.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD133/IMD133_Dermoscopic_Image/IMD133.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD134/IMD134_Dermoscopic_Image/IMD134.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD135/IMD135_Dermoscopic_Image/IMD135.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD137/IMD137_Dermoscopic_Image/IMD137.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD138/IMD138_Dermoscopic_Image/IMD138.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD139/IMD139_Dermoscopic_Image/IMD139.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD140/IMD140_Dermoscopic_Image/IMD140.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD142/IMD142_Dermoscopic_Image/IMD142.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD143/IMD143_Dermoscopic_Image/IMD143.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD144/IMD144_Dermoscopic_Image/IMD144.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD146/IMD146_Dermoscopic_Image/IMD146.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD147/IMD147_Dermoscopic_Image/IMD147.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD149/IMD149_Dermoscopic_Image/IMD149.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD150/IMD150_Dermoscopic_Image/IMD150.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD152/IMD152_Dermoscopic_Image/IMD152.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD153/IMD153_Dermoscopic_Image/IMD153.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD154/IMD154_Dermoscopic_Image/IMD154.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD155/IMD155_Dermoscopic_Image/IMD155.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD156/IMD156_Dermoscopic_Image/IMD156.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD157/IMD157_Dermoscopic_Image/IMD157.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD159/IMD159_Dermoscopic_Image/IMD159.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD160/IMD160_Dermoscopic_Image/IMD160.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD161/IMD161_Dermoscopic_Image/IMD161.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD162/IMD162_Dermoscopic_Image/IMD162.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD164/IMD164_Dermoscopic_Image/IMD164.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD166/IMD166_Dermoscopic_Image/IMD166.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD168/IMD168_Dermoscopic_Image/IMD168.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD169/IMD169_Dermoscopic_Image/IMD169.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD170/IMD170_Dermoscopic_Image/IMD170.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD171/IMD171_Dermoscopic_Image/IMD171.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD173/IMD173_Dermoscopic_Image/IMD173.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD175/IMD175_Dermoscopic_Image/IMD175.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD176/IMD176_Dermoscopic_Image/IMD176.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD177/IMD177_Dermoscopic_Image/IMD177.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD182/IMD182_Dermoscopic_Image/IMD182.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD196/IMD196_Dermoscopic_Image/IMD196.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD197/IMD197_Dermoscopic_Image/IMD197.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD198/IMD198_Dermoscopic_Image/IMD198.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD199/IMD199_Dermoscopic_Image/IMD199.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD200/IMD200_Dermoscopic_Image/IMD200.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD203/IMD203_Dermoscopic_Image/IMD203.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD204/IMD204_Dermoscopic_Image/IMD204.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD206/IMD206_Dermoscopic_Image/IMD206.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD207/IMD207_Dermoscopic_Image/IMD207.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD208/IMD208_Dermoscopic_Image/IMD208.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD210/IMD210_Dermoscopic_Image/IMD210.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD211/IMD211_Dermoscopic_Image/IMD211.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD219/IMD219_Dermoscopic_Image/IMD219.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD226/IMD226_Dermoscopic_Image/IMD226.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD240/IMD240_Dermoscopic_Image/IMD240.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD242/IMD242_Dermoscopic_Image/IMD242.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD243/IMD243_Dermoscopic_Image/IMD243.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD251/IMD251_Dermoscopic_Image/IMD251.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD254/IMD254_Dermoscopic_Image/IMD254.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD256/IMD256_Dermoscopic_Image/IMD256.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD278/IMD278_Dermoscopic_Image/IMD278.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD279/IMD279_Dermoscopic_Image/IMD279.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD280/IMD280_Dermoscopic_Image/IMD280.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD284/IMD284_Dermoscopic_Image/IMD284.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD285/IMD285_Dermoscopic_Image/IMD285.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD304/IMD304_Dermoscopic_Image/IMD304.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD305/IMD305_Dermoscopic_Image/IMD305.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD306/IMD306_Dermoscopic_Image/IMD306.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD312/IMD312_Dermoscopic_Image/IMD312.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD328/IMD328_Dermoscopic_Image/IMD328.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD331/IMD331_Dermoscopic_Image/IMD331.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD339/IMD339_Dermoscopic_Image/IMD339.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD347/IMD347_Dermoscopic_Image/IMD347.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD348/IMD348_Dermoscopic_Image/IMD348.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD349/IMD349_Dermoscopic_Image/IMD349.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD356/IMD356_Dermoscopic_Image/IMD356.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD360/IMD360_Dermoscopic_Image/IMD360.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD364/IMD364_Dermoscopic_Image/IMD364.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD365/IMD365_Dermoscopic_Image/IMD365.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD367/IMD367_Dermoscopic_Image/IMD367.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD368/IMD368_Dermoscopic_Image/IMD368.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD369/IMD369_Dermoscopic_Image/IMD369.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD370/IMD370_Dermoscopic_Image/IMD370.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD371/IMD371_Dermoscopic_Image/IMD371.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD372/IMD372_Dermoscopic_Image/IMD372.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD374/IMD374_Dermoscopic_Image/IMD374.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD375/IMD375_Dermoscopic_Image/IMD375.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD376/IMD376_Dermoscopic_Image/IMD376.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD378/IMD378_Dermoscopic_Image/IMD378.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD379/IMD379_Dermoscopic_Image/IMD379.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD380/IMD380_Dermoscopic_Image/IMD380.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD381/IMD381_Dermoscopic_Image/IMD381.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD382/IMD382_Dermoscopic_Image/IMD382.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD383/IMD383_Dermoscopic_Image/IMD383.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD384/IMD384_Dermoscopic_Image/IMD384.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD385/IMD385_Dermoscopic_Image/IMD385.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD386/IMD386_Dermoscopic_Image/IMD386.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD388/IMD388_Dermoscopic_Image/IMD388.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD389/IMD389_Dermoscopic_Image/IMD389.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD390/IMD390_Dermoscopic_Image/IMD390.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD392/IMD392_Dermoscopic_Image/IMD392.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD393/IMD393_Dermoscopic_Image/IMD393.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD394/IMD394_Dermoscopic_Image/IMD394.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD395/IMD395_Dermoscopic_Image/IMD395.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD396/IMD396_Dermoscopic_Image/IMD396.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD397/IMD397_Dermoscopic_Image/IMD397.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD398/IMD398_Dermoscopic_Image/IMD398.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD399/IMD399_Dermoscopic_Image/IMD399.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD400/IMD400_Dermoscopic_Image/IMD400.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD402/IMD402_Dermoscopic_Image/IMD402.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD403/IMD403_Dermoscopic_Image/IMD403.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD404/IMD404_Dermoscopic_Image/IMD404.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD405/IMD405_Dermoscopic_Image/IMD405.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD406/IMD406_Dermoscopic_Image/IMD406.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD407/IMD407_Dermoscopic_Image/IMD407.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD408/IMD408_Dermoscopic_Image/IMD408.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD409/IMD409_Dermoscopic_Image/IMD409.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD410/IMD410_Dermoscopic_Image/IMD410.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD411/IMD411_Dermoscopic_Image/IMD411.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD413/IMD413_Dermoscopic_Image/IMD413.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD417/IMD417_Dermoscopic_Image/IMD417.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD418/IMD418_Dermoscopic_Image/IMD418.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD419/IMD419_Dermoscopic_Image/IMD419.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD420/IMD420_Dermoscopic_Image/IMD420.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD421/IMD421_Dermoscopic_Image/IMD421.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD423/IMD423_Dermoscopic_Image/IMD423.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD424/IMD424_Dermoscopic_Image/IMD424.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD425/IMD425_Dermoscopic_Image/IMD425.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD426/IMD426_Dermoscopic_Image/IMD426.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD427/IMD427_Dermoscopic_Image/IMD427.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD429/IMD429_Dermoscopic_Image/IMD429.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD430/IMD430_Dermoscopic_Image/IMD430.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD431/IMD431_Dermoscopic_Image/IMD431.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD432/IMD432_Dermoscopic_Image/IMD432.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD433/IMD433_Dermoscopic_Image/IMD433.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD434/IMD434_Dermoscopic_Image/IMD434.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD435/IMD435_Dermoscopic_Image/IMD435.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD436/IMD436_Dermoscopic_Image/IMD436.bmp
# /dtu/datasets1/02516/PH2_Dataset_images/IMD437/IMD437_Dermoscopic_Image/IMD437.bmp

# %%
print('Loaded %d training images' % len(trainset))
print('Loaded %d test images' % len(testset))
# Out:
# Loaded 200 training images
# Loaded 200 test images

# %% [markdown]
# Let's look at some images from the dataset!

# %%
plt.rcParams['figure.figsize'] = [18, 6]

images, labels = next(iter(train_loader))

for i in range(6):
    plt.subplot(2, 6, i+1)
    plt.imshow(np.swapaxes(np.swapaxes(images[i], 0, 2), 0, 1))

    plt.subplot(2, 6, i+7)
    plt.imshow(labels[i].squeeze())
plt.show()

# %% [markdown]
# ## Device
#
# Check if GPU is available.

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)

# %% [markdown]
# First, we consider a simple encoder decoder network for image registration

# %%
class EncDec(nn.Module):
    def __init__(self):
        super().__init__()

        # encoder (downsampling)
        self.enc_conv0 = nn.Conv2d(3, 64, 3, padding=1)
        self.pool0 = nn.MaxPool2d(2, 2)  # 128 -> 64
        self.enc_conv1 = nn.Conv2d(64, 64, 3, padding=1)
        self.pool1 = nn.MaxPool2d(2, 2)  # 64 -> 32
        self.enc_conv2 = nn.Conv2d(64, 64, 3, padding=1)
        self.pool2 = nn.MaxPool2d(2, 2)  # 32 -> 16
        self.enc_conv3 = nn.Conv2d(64, 64, 3, padding=1)
        self.pool3 = nn.MaxPool2d(2, 2)  # 16 -> 8

        # bottleneck
        self.bottleneck_conv = nn.Conv2d(64, 64, 3, padding=1)

        # decoder (upsampling)
        self.upsample0 = nn.Upsample(16)  # 8 -> 16
        self.dec_conv0 = nn.Conv2d(64, 64, 3, padding=1)
        self.upsample1 = nn.Upsample(32)  # 16 -> 32
        self.dec_conv1 = nn.Conv2d(64, 64, 3, padding=1)
        self.upsample2 = nn.Upsample(64)  # 32 -> 64
        self.dec_conv2 = nn.Conv2d(64, 64, 3, padding=1)
        self.upsample3 = nn.Upsample(128)  # 64 -> 128
        self.dec_conv3 = nn.Conv2d(64, 1, 3, padding=1)

    def forward(self, x):
        # encoder
        e0 = self.pool0(F.relu(self.enc_conv0(x)))
        e1 = self.pool1(F.relu(self.enc_conv1(e0)))
        e2 = self.pool2(F.relu(self.enc_conv2(e1)))
        e3 = self.pool3(F.relu(self.enc_conv3(e2)))

        # bottleneck
        b = F.relu(self.bottleneck_conv(e3))

        # decoder
        d0 = F.relu(self.dec_conv0(self.upsample0(b)))
        d1 = F.relu(self.dec_conv1(self.upsample1(d0)))
        d2 = F.relu(self.dec_conv2(self.upsample2(d1)))
        d3 = self.dec_conv3(self.upsample3(d2))  # no activation
        return d3

# %% [markdown]
# ## Loss
#
# Now, as important as building the architecture is defining **the optimizer** and **the loss function.**
#
# The **loss function** is what we are trying to minimize. Many can be used. A popular one for binary segmentation is *binary cross-entropy* which is given by
#
# $$\mathcal L_{BCE}(y, \hat y) = -\sum_i \left[y_i\log\sigma(\hat y_i) + (1-y_i)\log(1-\sigma(\hat y_i))\right].$$
#
# where $y$ is the desired output and $\hat y$ is the output of the model. $\sigma$ is the [*logistic* function](https://en.wikipedia.org/wiki/Sigmoid_function) (also called *sigmoid*), which converts a real number $\mathbb R$ into a probability $[0,1]$.
#
# However, this loss suffers from numerical stability problems. Most importantly, $\lim_{x\rightarrow0}\log(x)=\infty$ which leads to optimization unstability. This loss [can be simplified](https://www.tensorflow.org/api_docs/python/tf/nn/sigmoid_cross_entropy_with_logits) into the following loss, which is equivalent and is not as prone to numerical unstability:
#
# $$\mathcal L_{BCE} = \hat y - y\hat y + \log\left(1+\exp(-\hat y)\right).$$

# %%
def bce_loss(y_real, y_pred):
    return torch.mean(y_pred - y_real*y_pred + torch.log(1 + torch.exp(-y_pred)))

# %% [markdown]
# Can you still see situations in which this loss might be unstable? How would you change it?

# %% [markdown]
# ## Training
#
# We will define the training cycle in a function so we can re-use it.

# %%
def train(model, opt, loss_fn, epochs, train_loader, test_loader):
    X_test, Y_test = next(iter(test_loader))

    for epoch in range(epochs):
        tic = time()
        print('* Epoch %d/%d' % (epoch+1, epochs))

        avg_loss = 0
        model.train()  # train mode
        for X_batch, Y_batch in train_loader:
            X_batch = X_batch.to(device)
            Y_batch = Y_batch.to(device)

            # set parameter gradients to zero
            opt.zero_grad()

            # forward
            Y_pred = model(X_batch)
            loss = loss_fn(Y_batch, Y_pred)  # forward-pass
            loss.backward()  # backward-pass
            opt.step()  # update weights

            # calculate metrics to show the user
            avg_loss += loss / len(train_loader)
        toc = time()
        print(' - loss: %f' % avg_loss)

        # show intermediate results
        model.eval()  # testing mode
        Y_hat = F.sigmoid(model(X_test.to(device))).detach().cpu()
        clear_output(wait=True)
        for k in range(6):
            plt.subplot(2, 6, k+1)
            plt.imshow(np.rollaxis(X_test[k].numpy(), 0, 3), cmap='gray')
            plt.title('Real')
            plt.axis('off')

            plt.subplot(2, 6, k+7)
            plt.imshow(Y_hat[k, 0], cmap='gray')
            plt.title('Output')
            plt.axis('off')
        plt.suptitle('%d / %d - loss: %f' % (epoch+1, epochs, avg_loss))
        plt.show()

# %% [markdown]
# ## Predict
#
# After the model is trained, you can use this function to predict segmentations for new data:

# %%
def predict(model, data):
    model.eval()  # testing mode
    Y_pred = [F.sigmoid(model(X_batch.to(device))) for X_batch, _ in data]
    return np.array(Y_pred)

# %% [markdown]
# ## Lights. Camera. Action.
#
# Let us instanciate the model and train it.

# %%
model = EncDec().to(device)
summary(model, (3, 256, 256))

# %%
train(model, optim.Adam(model.parameters()), bce_loss, 20, train_loader, test_loader)

# %% [markdown]
# -----------------------------------------------------------------------------------------
#
# # Other losses

# %% [markdown]
# <div style="border-left: solid 6px #d6d6d6; padding: 10px; background-color: #eaeaea">
# <b><i>Exercise:</i></b> Implement the following losses:
# <ol>
#     <li>Probabilistic Dice coefficient</li>
#     <li>Focal loss</li>
# </ol>
# </div>

# %% [markdown]
# **1. Dice coefficient:** Given two masks $X$ and $Y$, a common metric to measure the distance between these two masks is given by:
#
# $$D(X,Y)=\frac{2|X\cap Y|}{|X|+|Y|}$$
#
# This function is not differentiable and the loss function <b>must</b> always be differentiable for gradient descent to work. But we can approximate it using:
#
# $$\mathcal L_D(X,Y) = 1-\frac{mean(2X\cdot Y + 1)}{mean(X+Y) + 1},$$
# where $X\cdot Y$ is element-wise product of your image of pixel-wise confidences
#
# Implement this loss:

# %%
def dice_loss(y_real, y_pred):
    return ...

# %% [markdown]
# Run it:

# %%
model = EncDec().to(device)
train(model, optim.Adam(model.parameters(), 0.0001), dice_loss, 20, train_loader, test_loader)

# %% [markdown]
# **2. Focal loss:** First, remember how binary crossentropy looks like:
#
# $$\mathcal L_{BCE}(y, \hat y) = -\sum_i \left[y_i\log\sigma(\hat y_i) + (1-y_i)\log(1-\sigma(\hat y_i))\right].$$
#
# The problem with this loss is that it tends to benefit the **majority** class (usually the background) relative to the **minority** class (usually the foreground). Therefore, usually people apply weights to each class:
#
# $$\mathcal L_{wBCE}(y, \hat y) = -\sum_i \alpha_i\left[y_i\log\sigma(\hat y_i) + (1-y_i)\log(1-\sigma(\hat y_i))\right].$$
#
# Traditionally, the weight $\alpha_i$ is defined as the inverse frequency of the class of that pixel $i$, so that observations of the minority class weight more relative to the majority class.
#
# Another recent addition has been the **focal loss** which weights each pixel by the confidence we have in the prediction of that pixel.
#
# $$\mathcal L_{focal}(y, \hat y) = -\sum_i \left[\left(1-\sigma(\hat y_i)\right)^\gamma y_i\log\sigma(\hat y_i) + (1-y_i)\log(1-\sigma(\hat y_i))\right].$$
#
# A good value for $\gamma$ is generally 2.
#
# * Lin, Tsung-Yi, et al. "[Focal loss for dense object detection.](https://arxiv.org/pdf/1708.02002.pdf)" Proceedings of the IEEE international conference on computer vision. 2017.
#
# ------------------------------------------------------------------------------------------------------
#
# Implement focal loss:

# %%
def focal_loss(y_real, y_pred):
    return ...

# %%
model = EncDec().to(device)
train(model, optim.Adam(model.parameters(), 0.0001), focal_loss, 20, train_loader, test_loader)

# %% [markdown]
# ----------------------------------------------------------------------------------------------
#
# ## Regularization
#
# The more of our prior knowledge we can feed the neural network, the better. One way to introduce such background knowledge is by regularization. Regularization are extra terms added to the loss function.
#
# **Centered:** if you know the segmentation is always centered, you can punish it if it is not.
#
# $$\mathcal L_{centered}(y,\hat y) = 1-\sigma(\hat y_{w/2,h/2})$$
#
# **Sparsity:** if there is a lot of sparcity (small patches of segmentation), you can add an L1 term:
#
# $$\mathcal L_{sparcity} = \sigma(\hat y)$$
#
# **Contiguity:** to avoid many zig-zags in the semantic frontier, [total variation](https://en.wikipedia.org/wiki/Total_variation_denoising) can be used:
#
# $$\mathcal L_{contiguity} = \sum_{i,j}|\sigma(\hat y_{i+1,j})-\sigma(\hat y_{i,j})|+\sum_{i,j}|\sigma(\hat y_{i,j+1})-\sigma(\hat y_{i,j})|$$
#
# * Ferreira, P. M., Marques, F., Cardoso, J. S., & Rebelo, A. (2018). "[Physiological Inspired Deep Neural Networks for Emotion Recognition](https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=8472816&tag=1)". IEEE Access, 6, 53930-53943.

# %% [markdown]
# <div style="border-left: solid 6px #d6d6d6; padding: 10px; background-color: #eaeaea">
# <b><i>Exercise:</i></b> Add the total variation term to the loss.</div>

# %%
def bce_total_variation(y_real, y_pred):
    return bce_loss(y_real, y_pred) + 0.1*...

# %%
model = EncDec().to(device)
train(model, optim.Adam(model.parameters()), bce_total_variation, 20, train_loader, test_loader)

# %% [markdown]
# -----------------------------------------------------------------------------------------
#
# # U-Net
#
# A [**U-Net**](https://arxiv.org/abs/1505.04597) is a neural network architecture that receives an image and outputs an image. It was originally conceived for semantic segmentation (as we will use it), but it is so successfully that it has since been used in other contexts. Given a medical image, it outputs a grayscale image representing the probability of each pixel being the region of interest.
#
# <img src="data:image/png;base64,...">

# %% [markdown]
# Like the encoder-decoder network, this architecture is composed by two parts: Half of the network applies convolutions and pooling layers to successively reduce the input image (*encoder*). The other half successively increases the size of the image (*decoder*). In the end, we have an output image with the same size as the input image, but the number of channels might be different (e.g. the output might be grayscale and the input can be RGB).
#
# Unlike the encoder-decoder network, U-Net adds skip-connections:
#
# <img src="data:image/png;base64,...">
#
# Notice that the activation map along the encoder decoder network are symmetric. That is, the size of the activation map in the 1st layer is equal to the size of the last layer, the size of the 2nd layer's activations is equal to the penultimate activations, etc. The authors took advantage of this fact to introduce skip-connections to further improve the performance of the networks. What these skip-connections do is to connect each layer not only to the previous layer, but also to its twin layer. This allows gradients to travel more freely (avoiding things like vanishing gradients) and also helps avoid checkboard artifacts which sometimes plagues this type of networks.
#
# This can be done during `fpass` by concatenating (`torch.cat`) the encoding output to the respective decoding input. For example, `torch.cat([d0, e2], 1)`.
#
# * Ronneberger, Olaf, Philipp Fischer, and Thomas Brox. "[U-Net: Convolutional networks for biomedical image segmentation.](https://arxiv.org/pdf/1505.04597.pdf)" International Conference on Medical image computing and computer-assisted intervention. Springer, Cham, 2015.

# %% [markdown]
# <div style="border-left: solid 6px #d6d6d6; padding: 10px; background-color: #eaeaea">
#     <b><i>Exercise:</i></b> Copy the <tt>EncDec</tt> model and rename it to <tt>UNet</tt>. Then introduce the skip connections using <tt>torch.concat</tt> in the <tt>forward()</tt> function. In the end, you will also need to adjust the input size of each convolution in the constructor.
# </div>

# %%
model = UNet().to(device)
summary(model, (3, 256, 256))

# %% [markdown]
# This summary is no longer useful to see the model, since the model is no longer sequential. Therefore, we will use the package `torchviz` to draw a diagram of the model you implemented:

# %%
from torchviz import make_dot
make_dot(model(torch.randn(20, 3, 256, 256).cuda()), params=dict(model.named_parameters()))

# %%
torch.cuda.empty_cache()
train(model, optim.Adam(model.parameters()), bce_loss, 20, train_loader, test_loader)

# %% [markdown]
# ---------------------------------------------------------------------------------------------------
#
# So far, we have been using **Max-Pooling** for the downsampling and **nearest-neighbor Upsampling** for the upsampling.
#
# Down-sampling:
#
#         conv = nn.Conv2d(3, 64, 3, padding=1)
#         pool = nn.MaxPool2d(3, 2, padding=1)
#
# Up-Sampling
#
#         upsample = nn.Upsample(32)
#         conv = nn.Conv2d(64, 64, 3, padding=1)
#
# As been discussed last week, downsample can also be done with stride=2, and upsample with stride=1/2. This generally works better than using max-pooling and upsample.

# %% [markdown]
# <div style="border-left: solid 6px #d6d6d6; padding: 10px; background-color: #eaeaea">
# <b><i>Exercise:</i></b> Replace max-pooling by convolutions with stride=2, and replace upsampling by transpose-convolutions also with stride=2.
# </div>

# %%
class UNet2:
    ....
    ....

# %%
model = UNet2().to(device)
summary(model, (3, 256, 256))

# %%
train(model, optim.Adam(model.parameters()), bce_loss, 20, train_loader, test_loader)

# %% [markdown]
# # Dilated convolutions
#
# We have been using encoder-decoder architectures, which are the most popular. But other architectures exist. For example, we could have used so-called **dilated convolutions** as an alternative to downsampling via pooling or striding
#
# <img src="data:image/png;base64,...">
#
# In the first layer, we use dilation=1, the second layer uses dilation=2, and so on, until a good part of the receptive field is reached.
#
# * Yu, Fisher, and Vladlen Koltun. "[Multi-scale context aggregation by dilated convolutions.](https://arxiv.org/pdf/1511.07122.pdf)" arXiv preprint arXiv:1511.07122 (2015).

# %% [markdown]
# <div style="border-left: solid 6px #d6d6d6; padding: 10px; background-color: #eaeaea">
# <b><i>Exercise:</i></b> Copy the encoder decoder network and implement a <tt>DilatedNet</tt> using dilated filters instead of down-sampling and up-sampling.
# </div>

# %%
class DilatedNet:
    ....
    ....

# %%
model = DilatedNet().to(device)
summary(model, (3, 256, 256))

# %%
train(model, optim.Adam(model.parameters()), bce_loss, 20, train_loader, test_loader)

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------
#
# # Multi-class Segmentation
#
# 1. Use the [CMP-Facade dataset](http://cmp.felk.cvut.cz/~tylecr1/facade/) that you find at
#
#     /dtu/datasets1/02516/CMP_facade_DB_base
#
# 2. Load the dataset. There are 12 classes, therefore, each segmentation will have the shape $12\times H\times W$.
# 3. Copy over one of the previous models and adapt for multi-class segmentation. The most important change is the to *loss function.* Feel free to use [this pytorch loss](https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html#torch.nn.CrossEntropyLoss) which implements softmax-crossentropy.

# %% [markdown]
# Load:

# %% [markdown]
# Model:

# %% [markdown]
# Training:

# %% [markdown]
# -----------------------------------------------------------------------------------------
#
# # Further Thoughts
#
# 1. Especially when there is little data, **transfer-learning** can also be used for segmentation. A popular approach is to replace the encoder part of the U-Net by the convolutional part of VGG-16.
# 2. **Data augmentation** can also be used to improve segmentation quality. Special care must be taken because (i) some augmentation is symmetric and must be applied in pairs like rotation, and (ii) some augmentation is asymmetric like brightness.
# 3. We have covered here *semantic* segmentation. What could we have done differently for *instance* segmentation?
